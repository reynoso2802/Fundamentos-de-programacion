# %% [markdown]
# Semana 7

# %% [markdown]
# Ejercicio 1

# %%
archivo = open("saludo.txt",mode="a")
archivo.write("Esta es la tercera linea\n")
archivo.close()
print("Se ha escrito en el archivo saludo.txt")
# Out:
# Se ha escrito en el archivo saludo.txt

# %% [markdown]
# Ejercicio 2

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("Esto es una primera linea\n")
    archivo.write("Esto es una segunda linea\n")
    archivo.write("Esto es una tercera linea\n")

with open("bitacora.txt", mode ="a") as archivo:
    archivo.write("Esto es una cuarta linea\n")

# %% [markdown]
# ____________

# %%
nombre = input("Ingresa tu nombre: ")
edad = input("Ingresa tu edad: ")

with open ("datos_usuario.txt", mode ="w")as archivo:
    archivo.write(f"Nombre: {nombre}, Edad: {edad}\n")

with open("datos_usuario.txt", mode ="a") as archivo:
    archivo.write("Esto es una segunda linea\n")

print("Datos guardados")
# Out:
# Datos guardados

# %% [markdown]
# Lectrua

# %%
with open ("LCQSACLD.txt", mode="r") as a:
    contenido = a.read()

print (contenido)
# Out:
# La computadora de Evelyn👾
# que se apaga 😭
# cuando la desconectas 🙀
# y ahora 😼
# se apaga de repente ☠️
# aunque esté conectada 😪

# %% [markdown]
# ej 10

# %%
archivo = open("nombres.txt", mode="r")

lineas = archivo.readlines()

for i, linea in enumerate(lineas, start=1):
    print(i, ".", linea )

archivo.close()
# Out:
# 1 . Eduardo
#
# 2 . Luis
#
# 3 . Juan

# %% [markdown]
# Ej 11

# %%
archivo = open("frutas.txt", mode="r")

for linea in archivo:
    print("Me gustan las:", linea)

archivo.close()
# Out:
# Me gustan las: Sandías
#
# Me gustan las: Peras
#
# Me gustan las: Uvas

# %% [markdown]
# Ej 14

# %%
archivo = open("articulo.txt", mode="r")

for linea in archivo:
    if "Python" in linea:
        print (linea)

archivo.close()
# Out:
# Python es facil
#
# Python es poderoso
#
# Python se ejecuta en la mac

# %% [markdown]
# Ej 15

# %%
archivo = open("numeros.txt", mode="r")

suma = 0


for linea in archivo:
    suma += int (linea)

archivo.close()

print("La suma de los numeros es:", suma)
# Out:
# La suma de los numeros es: 100
