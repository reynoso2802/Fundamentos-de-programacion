# %%
calificacion = 90
conducta = 1


if calificacion >= 90:
    print ("A")
    if conducta >= 9:
     print ("Tu conducta es excelente")
elif calificacion >= 80:
    print ("B")
    if conducta >= 8:
        print ("Tu conducta es buena ")
elif calificacion >= 70:
    print ("D")
    if conducta >= 7:
        print ("Tu conducta es regular")
elif calificacion >= 60:
    print ("D")
    if conducta >= 6:
        print ("Tu conducta es mala")
else:
    print ("E")
    print ("Tu conducta es pesima")
# Out:
# A

# %%
PL1 = True 
PL2 = False 

print (PL1 or PL2)
# Out:
# True

# %%
edad = 65 
tipo = "adulto_mayor"

es_mayor = edad >= 18 
print (es_mayor)
aplica_descuento = (edad >= 60) and (tipo == "adulto_mayor")
print (aplica_descuento)
# Out:
# True
# True

# %%
edad = int(input("Ingresa tu edad:"))
if (edad < 0 ):
    print ("Aguanta, no hay edades menores a 0 ")
else:
    print ("Ahora si vamos a trabajar con edades reales")
# Out:
# Ahora si vamos a trabajar con edades reales

# %%
tabla = 8 
for n in range (10):
    print (f"{tabla}" x {n} )

# %% [markdown]
# Ejercicios

# %% [markdown]
# Ejercicio 1

# %%
edad = int(input("Ingresa tu edad:"))

if (edad >=18):
    print ("Eres mayor de edad")
else: 
    print ("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# Ejercicio 2

# %%
numero = int(input("Ingresa un numero entero:"))

if (numero % 2 == 0):
    print("Es un mismo par")
else:
    print ("Es un numero impar")
# Out:
# Es un numero impar

# %% [markdown]
# Ejercicio 3

# %%
cal = int(input("Ingresa tu calificación:"))
if (cal >= 6):
    print ("Aprobado")
else:
    print ("Reprobado")
# Out:
# Aprobado

# %% [markdown]
# Ejercicio 4

# %%
edad = int(input("Ingresa tu Edad:"))
if edad <= 3:
    print ("Bebé")
elif edad <= 12:
    print ("Niño")
elif edad <= 13:
    print ("Adolescente")
else:
    print ("Adulto")
# Out:
# Bebé

# %% [markdown]
# Ejercicio 5

# %%
tipo = str(input("Ingresa tipo de visitante:")) 
precio = 45

if tipo == "adulto_mayor":
    descuento = precio * 0.12  
elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.10 
else:
    descuento = 0

total = precio - descuento 

print (f"Total a pagar: ${total}")
# Out:
# Total a pagar: $40.5

# %% [markdown]
# Ejercicio 6

# %%
edad = int(input("Ingresa tu edad:"))
if (edad >= 18):
    print ("Acceso permitido")
else:
    print ("Acceso No Permitido")
# Out:
# Acceso No Permitido

# %% [markdown]
# Ejercicio 7

# %%
num1 = float(input("Ingresa un numero:"))
num2 = float(input("Ingresa un numero:"))
if num1 < 0 or num2 < 0:
    print("Hay un número negativo")
# Out:
# Hay un número negativo

# %% [markdown]
# Ejercicio 8

# %%
num = float(input("Ingresa un numero:"))

if num => 0

# %% [markdown]
# Ejercicio 9

# %%
acc = str(input("¿Desea continuar? "))

if not acc == "si":
    print("Proceso finalizado")
# Out:
# Proceso finalizado
