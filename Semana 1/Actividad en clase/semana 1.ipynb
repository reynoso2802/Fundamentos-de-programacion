# %% [markdown]
# #Sesión 1
#
# Este archivo es para 2 cosas:
# 1. Familiariazrnos con  Jupyter Notebook
# 2. Practicar python

# %%
print ("hola :)")
# Out:
# hola :)

# %% [markdown]
# ## Variables
#
# Las variables en python son tipos de datos que tienen diferente forma
#
# * Numericas (Enteros Flotante)
# * Cadenas de carecteres
# * Booleanos
# * Compuestos

# %%
Nombre = "Eduardo" 
Edad = 22
es_estudiante = True
esta_activo = None

print(type(Nombre))
print (type(Edad))
print(type(es_estudiante))
print(type(esta_activo))      


print ("Hola" , Nombre, "ya vi que tienes", Edad, "años de edad")
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>
# Hola Eduardo ya vi que tienes 22 años de edad

# %% [markdown]
# En este punto incialice el protyecto en Git

# %% [markdown]
# ## Algoritmo para calcular velocidad

# %%
Distancia = int(input("Ingrese la distancia en kilometros"))
Tiempo = int(input("Ingresa el timepo en horas"))

print("El dato distancia es de tipo: ", type (Distancia))
print("El dato tiempo es de tipo: ", type (Tiempo))

velocidad = Distancia / Tiempo 

print ("La velocidad promedio es:", velocidad)
# Out:
# El dato distancia es de tipo:  <class 'int'>
# El dato tiempo es de tipo:  <class 'int'>
# La velocidad promedio es: 0.4

# %%
nombre = str(input("Ingresa tu nombre:"))
edad = int(input("Ingresa tu edad:"))

print("Hola " + nombre + "tu edad es " + str (edad))
# Out:
# Hola Eduardo tu edad es 22

# %%
celsius = int(input("Ingresa la temperatura en grados centigraddos:"))

farenheit = celsius * 1.8 + 32
kelvin = celsius + 273.15

print ("La temperatura en Farenheit es " + str(farenheit) + " y en kelvin " + str(kelvin))
# Out:
# La temperatura en Farenheit es 75.2 y en kelvin 297.15
