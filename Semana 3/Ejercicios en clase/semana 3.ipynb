# %% [markdown]
# Ejercicio 1

# %% [markdown]
# Ejercicio 2

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# Ejercicio 4

# %% [markdown]
# Ejercicio 5

# %% [markdown]
# Ejercicio 6

# %% [markdown]
# Ejercicio 7

# %%
numero = float(input("Ingresa un numero entero"))

if numero % 2 == 0:
    print ("El " + str(numero) +" es numero par")
elif not numero == float:
    print("Se pidio un numero entero, se finaliza el proceso")
else:
    print(("El " + str(numero) +" es numero impar"))
# Out:
# El 8.0 es numero par

# %% [markdown]
# Ejercicio 8

# %%
num1 = int(input("Ingresa el primer numero"))
num2 = int(input("ingresa el segundo numero "))
num3 = int(input("Ingresa el tercer numero"))

if num1 > num2 and num1 > num3:
    print("El mayor es:", num1)
elif num2 > num1 and num2 > num3:
    print("El mayor es:", num2)
else:
    print("El mayor es:", num3)
# Out:
# El mayor es: 45

# %% [markdown]
# Ejercicio 11

# %%
suma = 0

numero = float(input("Ingresa un número: "))

while numero != 0:
    if numero > 0:
        suma = suma + numero

    numero = int(input("Ingresa otro número: "))

print("La suma es:", suma)
# Out:
# La suma es: 9.0
