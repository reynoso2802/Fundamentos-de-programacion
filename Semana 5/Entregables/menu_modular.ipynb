# %%
#Funciones

def sumar_numeros(numeros):

    suma = 0

    for n in numeros:
        suma = suma + n

    return suma


def buscar_contacto(contactos, nombre):

    if nombre in contactos:
        return contactos[nombre]

    else:
        return None


def contar_palabras(mensaje):

    palabras = mensaje.split()

    return len(palabras)


def tuplas():

    numeros = (5, 8, 3, 10, 2)

    print("Tercer elemento:", numeros[2])

    num1 = float(input("Ingresa un número: "))
    num2 = float(input("Ingresa otro número: "))

    nueva_tupla = numeros + (num1, num2)

    print("Nueva tupla:", nueva_tupla)

    lista = list(nueva_tupla)
    lista.sort()

    print("Lista ordenada:", lista)

    total = sumar_numeros(nueva_tupla)

    print("Suma total:", total)


def diccionarios():

    contactos = {
        "Ana": "555-0101",
        "Luis": "555-0102",
        "Mía": "555-0103"
    }

    nombre = input("Ingresa el nombre del nuevo contacto: ")
    telefono = input("Ingresa el número de teléfono: ")

    contactos[nombre] = telefono

    print("Contactos registrados:")

    for contacto in contactos.keys():
        print(contacto)

    buscar = input("Ingresa el nombre que quieres buscar: ")

    resultado = buscar_contacto(contactos, buscar)

    if resultado != None:
        print("Teléfono:", resultado)

    else:
        print("Contacto no encontrado")


def excepciones():

    try:

        num1 = int(input("Ingresa el primer número entero: "))
        num2 = int(input("Ingresa el segundo número entero: "))

        suma = num1 + num2

        print("Suma:", suma)

        try:

            division = num1 / num2

            print("División:", division)

        except ZeroDivisionError:

            print("Error: No es posible dividir entre cero")

    except ValueError:

        print("Error: Ingresa solamente números enteros")


def strings():

    mensaje = "Python es un lenguaje poderoso"

    print("Longitud del mensaje:", len(mensaje))

    print("En mayúsculas:", mensaje.upper())

    nuevo_mensaje = mensaje.replace("Python", "programación")

    print("Texto reemplazado:", nuevo_mensaje)

    total = contar_palabras(mensaje)

    print("Palabras totales:", total)


#Menu 

opcion = 0

while opcion != 5:

    print("\nMENÚ PRINCIPAL")
    print("1. Tuplas")
    print("2. Diccionarios")
    print("3. Excepciones")
    print("4. Strings")
    print("5. Finalizar")

    try:

        opcion = int(input("Selecciona una opción: "))

        if opcion == 1:

            tuplas()

        elif opcion == 2:

            diccionarios()

        elif opcion == 3:

            excepciones(

        elif opcion == 4:

            strings()

        elif opcion == 5:

            print("Programa finalizado")

        else:

            print("Ingresa una opción del 1 al 5")

    except ValueError:

        print("Ingresa 5una opción numérica")
# Out:
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Contactos registrados:
# Ana
# Luis
# Mía
# Eduardo
# Contacto no encontrado
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Contactos registrados:
# Ana
# Luis
# Mía
# Juanpa
# Teléfono: 77654356778
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Contactos registrados:
# Ana
# Luis
# Mía
#
# Contacto no encontrado
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Ingresa una opción numérica
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Suma: 4
# División: 1.0
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Suma: 4
# División: 1.0
#
# MENÚ PRINCIPAL
# 1. Tuplas
# 2. Diccionarios
# 3. Excepciones
# 4. Strings
# 5. Finalizar
# Tercer elemento: 3
# ...
