# %%
calificaciones = 

nuevas_calificaciones =

# %%
desordenada = (9,2,7.10,0,8,14,22,4)

print(type(desordenada))
print(desordenada)
lista = list(desordenada)
print()
print (type(lista))
print (lista)

print()
lista.sort()
print(lista)
ordenada = tuple(lista)
print()
print(type(ordenada))
print(ordenada)
# Out:
# <class 'tuple'>
# (9, 2, 7.1, 0, 8, 14, 22, 4)
#
# <class 'list'>
# [9, 2, 7.1, 0, 8, 14, 22, 4]
#
# [0, 2, 4, 7.1, 8, 9, 14, 22]
#
# <class 'tuple'>
# (0, 2, 4, 7.1, 8, 9, 14, 22)

# %% [markdown]
# Diccionarios

# %%
contactos = {
    "Eduardo" : "7731734527" ,
    "Juan" : "3456453672" , 
    "Andrea" : "2223456887"
}

print(contactos["Eduardo"])

contactos["Cris"] = "2233446655"
contactos["Ricardo"] = "2238233673"

print(contactos)
# Out:
# 7731734527
# {'Eduardo': '7731734527', 'Juan': '3456453672', 'Andrea': '2223456887', 'Cris': '2233446655', 'Ricardo': '2238233673'}

# %%
print(contactos.keys())
print(contactos.values())
print(contactos.items())
# Out:
# dict_keys(['Eduardo', 'Juan', 'Andrea', 'Cris', 'Ricardo'])
# dict_values(['7731734527', '3456453672', '2223456887', '2233446655', '2238233673'])
# dict_items([('Eduardo', '7731734527'), ('Juan', '3456453672'), ('Andrea', '2223456887'), ('Cris', '2233446655'), ('Ricardo', '2238233673')])

# %%
print ("impresión de laves")
for n in contactos.keys():
    print(n)

print ("\nimpresión de valores")
for v in contactos.values():
    print(v)

print ("\nimpresión completa")
for n, t in contactos.items():
    print(f"Nombre: {n} , telefono: {t}")
# Out:
# impresión de laves
# Eduardo
# Juan
# Andrea
# Cris
# Ricardo
#
# impresión de valores
# 7731734527
# 3456453672
# 2223456887
# 2233446655
# 2238233673
#
# impresión completa
# Nombre: Eduardo , telefono: 7731734527
# Nombre: Juan , telefono: 3456453672
# Nombre: Andrea , telefono: 2223456887
# Nombre: Cris , telefono: 2233446655
# Nombre: Ricardo , telefono: 2238233673

# %%
def buscar_contacto(contactos, nombre):
    return contactos.get (nombre, "Contacto no disponible")

nombre = input("Escribe el nombre del contacto que buscas")
telefono = buscar_contacto(contactos, nombre)
print (f"El telefono de {nombre} es: {telefono}")
# Out:
# El telefono de Eduardo es: 7731734527

# %%
try: 
    edad = int(input("Ingresa tu edad:"))
    print(f"Tu edad es {edad}")
except ValueError:
    print("ERROR:DEBES INGRESAR SOLO NUMEROS ENTEROS")
# Out:
# ERROR:DEBES INGRESAR SOLO NUMEROS ENTEROS

# %%
try:
    dividendo = int(input("Ingresa un numero: "))
    divisor = int(input("Ingresa entre numero se dividirá: "))
    result = dividendo/divisor

except ValueError:
    print ("Error de division entre 0")
else:
    print(f"El resultado es {result}")
finally:
    print("Adiooooooooos")
# Out:
# El resultado es 1.0
# Adiooooooooos

# %%
print(nombre.upper())
print(nombre.lower())
print(nombre.capitalize())
# Out:
# EDUARDO
# eduardo
# Eduardo

# %% [markdown]
# Desafio extra  2

# %%
candidatos = {
    "A" : 0,
    "B" : 0,
    "C" : 0
    }

cantidad = int(input("Cuantos votos serán?: "))
conteo = 1

while conteo <= cantidad: 
    voto = input(f"ingresa el voto {conteo} (A,B,C):")
    if voto.upper () in candidatos:
        print(f"Voto válido para {voto.upper()}")
        candidatos[voto.upper()] += 1
        conteo += 1
    else:
        print("El voto no es valido, vota nuevamente")

print("\nResultados:")
for k, v in candidatos.items():
    print (f"Opcion {k}, votos {v}")
# Out:
# votaste por A
# Voto para A
# Opcion A, votos 1
# Opcion B, votos 0
# Opcion C, votos 0
